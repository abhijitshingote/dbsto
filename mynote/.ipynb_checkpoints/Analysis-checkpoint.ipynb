# %%
import psycopg2 as psy
import pandas as pd
import sqlalchemy
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sqlalchemy.__version__
# Out:
# '1.3.8'

# %%
# conn=psy.connect('postgresql://postgres:mypassword@backend-db:5432/postgres')

host = 'backend-db'
db = 'dbsto'
user='postgres'
password='mypassword'
engine = sqlalchemy.create_engine(f"postgresql://{user}:{password}@{host}:5432/{db}")
conn = engine.connect()

# %%
df=pd.read_sql_query('''select * from public.stock_price_history''',conn)
df=df[~df.isna()]

# %%
plt.figure(figsize=[10,15])
df[df.symbol=='AMZN']['Close'].plot()

# %%
df[df.symbol=='AAPL']
# Out:
#             Date        Open        High         Low       Close       Volume  \
# 22517 2020-11-09         NaN         NaN         NaN         NaN          NaN
# 22518 2020-11-10  115.550003  117.589996  114.129997  115.970001  138023400.0
# 22519 2020-11-11  117.190002  119.629997  116.440002  119.489998  112295000.0
# 22520 2020-11-12  119.620003  120.529999  118.570000  119.209999  103162300.0
# 22521 2020-11-13  119.440002  119.669998  117.870003  119.260002   81581900.0
# ...          ...         ...         ...         ...         ...          ...
# 22766 2021-11-04  151.580002  152.429993  150.639999  150.960007   60394600.0
# 22767 2021-11-05  151.889999  152.199997  150.059998  151.279999   65414600.0
# 22768 2021-11-08  151.410004  151.570007  150.160004  150.440002   55020900.0
# 22769 2021-11-09  150.199997  151.429993  150.059998  150.809998   56722500.0
# 50532 2021-11-09  150.199997  151.427994  150.070007  150.809998   52994252.0
#
#       symbol
# 22517   AAPL
# 22518   AAPL
# 22519   AAPL
# 22520   AAPL
# 22521   AAPL
# ...      ...
# 22766   AAPL
# 22767   AAPL
# 22768   AAPL
# 22769   AAPL
# 50532   AAPL
#
# [254 rows x 7 columns]

# %%
sns.lineplot(data=df,x='Date',y='Close')
